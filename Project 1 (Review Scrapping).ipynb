# %%
from flask import Flask, render_template, request, jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"iphone13"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone13'

# %%
response_website = urreq(flipkart_url)

# %%
data_flipkart= response_website.read()

# %%
beautified_html = bs(data_flipkart,"html.parser")

# %%
beautified_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = beautified_html.find_all('div',{"class":"_1AtVbE col-12-12"})

# %%
bigbox[0]  #reach div tag [0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone13&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,
# ...

# %%
bigbox[6].div.div.div.a["href"]
# Out:
# '/apple-iphone-13-product-red-128-gb/p/itm99b5658d148b0?pid=MOBG6VF59ZFEPEBX&lid=LSTMOBG6VF59ZFEPEBXH3IWCE&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=d26ce530-6352-4e20-bf9c-f721f0004bff.MOBG6VF59ZFEPEBX.SEARCH&ppt=None&ppn=None&ssid=pm7higksn40000001673757108951&qH=7d4afaedfc628b80'

# %%
product6 ="https://www.flipkart.com/search?q="+"iphone13"+bigbox[6].div.div.div.a["href"]

# %%
import requests

# %%
product66 = requests.get(product6)

# %%
product6
# Out:
# 'https://www.flipkart.com/search?q=iphone13/apple-iphone-13-product-red-128-gb/p/itm99b5658d148b0?pid=MOBG6VF59ZFEPEBX&lid=LSTMOBG6VF59ZFEPEBXH3IWCE&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=d26ce530-6352-4e20-bf9c-f721f0004bff.MOBG6VF59ZFEPEBX.SEARCH&ppt=None&ppn=None&ssid=pm7higksn40000001673757108951&qH=7d4afaedfc628b80'

# %%
product66.encoding='utf-8'

# %%
product6_page = bs(product66.text,"html.parser")

# %%
all_review = product6_page.find_all('div', {"class":"_16PBlm"})

# %%
all_review[5]
# Out:
# <div class="_16PBlm _3_IKGE"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Fabulous!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Picture quality is amazing you do not need to think twice about buying this for performance and photos, just go for it. Bionic A 15 is super fast and it has amazing performance, <br/>It is specially good for gaming although battery backup is not that good if you are a heavy user,<br/>But if you are a light or medium user it will give you battery backup of whole day in one charge.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_e3g3sjac.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(h
# ...

# %%
rating = all_review[5].div.div.div.div.text

# %%
all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Maharshi Pandey</p>]

# %%
all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">Maharshi Pandey</p>

# %%
name = all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
name
# Out:
# 'Maharshi Pandey'

# %%
rating
# Out:
# '5'

# %%
comment_header= all_review[5].div.div.div.p.text

# %%
comment_header
# Out:
# 'Fabulous!'

# %%
all_review[5].div.find_all('div',{"class":""})[0].div.text
# Out:
# 'Picture quality is amazing you do not need to think twice about buying this for performance and photos, just go for it. Bionic A 15 is super fast and it has amazing performance, It is specially good for gaming although battery backup is not that good if you are a heavy user,But if you are a light or medium user it will give you battery backup of whole day in one charge.'

# %%
all_review[5].div.find_all('p',{"class":"_2sc7ZR"})[1].text
# Out:
# '3 months ago'

# %%
_30jeq3

# %%
product6_page.find_all('div',{"class":"_30jeq3"})[0].text
# Out:
# '₹59,499'

# %%
for i in all_review:
    cost = product6_page.find_all('div',{"class":"_30jeq3"})[0].text
    date_review= i.div.find_all('p',{"class":"_2sc7ZR"})[1].text
    long_review = i.div.find_all('div',{"class":""})[0].div.text
    comment_header= i.div.div.div.p.text
    name = i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    rating = i.div.div.div.div.text
    print(name,rating,comment_header,"",date_review,cost,long_review,"\n")
    print()
# Out:
# Arnab Das 5 Perfect product!  2 months ago ₹59,499 Awesome battery backup amazing camera, a all day batter backup  improved and brilliant IOs 16.1 oled display dolby speakers and lot more, just close your eyes and go for it. One of the best handy smartphones ever and in great discount given by flipkart in big billion days 🔥
#
#
# Flipkart Customer 5 Excellent  2 months ago ₹59,499 I upgraded to 13 from xs and my experience with this had been extraordinary . The user interface and the camera is too good .Just in love with this extraordinary device .I just shared some photos clicked from this phone so that everyone can have an idea about how good the camera is compared all other flagship devices . The lens inside the device is so efficient that it  automatically reduces the noise in the picture making it very crisp and clear  .
#
#
# ...

# %%
import mysql.connector as conn

mydb = conn.connect(host = "localhost" , user = "root" , passwd = "ankurwavey.2")
cursor = mydb.cursor()
cursor.execute("create database if not exists review")
cursor.execute("create table if not exists review.store_review (price varchar(30), comment_header varchar(90), name varchar(90), rating varchar(90), long_review varchar(90))")
mydb.commit()
